# %%
import numpy as np
import pandas as pd

π = np.pi

# %%
# # Do335 Analysis


# The 3D model(`Do335.stl`) of the aircraft is used to obtain mesurements

# Credits for the model: 
# "Dornier Do 335 Pfeil" (https://skfb.ly/6RvqN) by helijah is licensed under Creative Commons Attribution (http://creativecommons.org/licenses/by/4.0/).



# ### Basic aircraft parameters

# - Length: 13.85 m
# - Wingspan(b): 13.8 m
# - Height including landing gear and tail: 4.86 m
# - Height of landing gear: 1.90 m
# - Height of CG = 0.9

# - Wing area(S): 38.5 m $^2$
# > - Max takeoff weight: 

# - Empty Weight: 7,400 kg
# - Normal Loaded: 9,610 kg
# - Service Ceiling: 11,400 m
# - Normal Range: 1,380 km
# - Cruise speed: 685 km/h at 7,200 m (Mach 0.61)
# - Economical cruise speed: 452 km/h at 6,000 m (Mach 0.37)
# - VMO: Mach 0.85
# - Max speed: 763 km/h at 6,500 m
# - Landing speed: 180 km/h
# #### Fuselage
# - Fuselage volume: 59.2 m $^3$
# - Width: 1.18 m
# - Height: 1.87 m
# #### Engine/Powerplant
# - Powerplant: 1x Daimler-Benz DB-603A and 1x Daimler-Benz DB-603QE

#     - Daimler-Benz DB-603A
#       -   Type: Inline, 12-cylinder
#       -   Cooling type: Water
#       -   Engine Power
#       -   Maximum: 1,580 hp
#       -   WEP: 1,750 hp



#     - Daimler-Benz DB-603QE
#          - Type: Inline, 12-cylinder
#          - Cooling type: Water
#          - Engine Power:
#          - Maximum 1,580 hp
#          - WEP 1,750 hp

# #### Propellor
# ##### Forward propellor:
# - Blade count: 3
# - Diameter: 3.60 m
# - Height: 0.7 m

# ##### Aft propellor:
# - Blade count: 3
# - Diameter: 3.60 m
# - Height: 1.2 m
# #### Control surfaces

# ##### Main Wing
# - LocationX: 8.095 m
# - Height: 0.35 m
# - Wing Semi-span: 6.90 m
# - Wing Root Chord: 3.80 m
# - Wing Tip Chord: 1.90 m
# - Dihedral angle: 4.578°
# - Airfoil: root: NACA 23018-630; tip: NACA 23012-635
# ###### Ailerons
# - Root distance from center: 3.35 m
# - Tip distance from center: 6.31 m
# - Root cchord: 0.51 m
# - Tip chord: 0.386 m
  


# ##### Horizonatal Tail
# Symmetric - 2 HTs
# - HT Location: 2.04 m
# - HT Semi-span: 2.6 m
# - HT Root Chord: 1.63 m
# - HT Tip Chord: 1.07 m
# - Area: 6.40
# ###### Elevator
# Symmetric - 2 elevators
# - Root distance from center: 0.30 m
# - Tip distance from center: 2.69 m
# - Root chord: 0.6 m
# - Tip chord: 0.37 m

# ##### Vertical tail

# Symmetric - 2 VTs
# - VT location: 1.9 m
# - VT height: 1.2 m
# - VT half span 1.95 m
# - VT surface area = 3.56 m $^2$
# - VT root chord = 1,703 m
# - VT tip chord = 0.702 m


# ###### Rudder
# Symmetric - 2 rudders
# - Top rudder vertical start positions: 1.6 m
# - Top rudder vertical end position: 2.8 m
# - Rudder root chord: 0.5 m
# - Rudder tip chord: 0.31 m

# %%
#Primary quantities
kmh_to_ms = 5/18
Vinfty = 452*kmh_to_ms
altitude = 6000
rho = 0.6601 
w_cr = 3.80
w_ct = 1.90
b = 13.8
S = 38.5
Temperature = 255.65
γ = 1.4
R = 287
iw = 0
it = 5 * π/180
S_ht = 7.55
b_ht = 5.2
S_ht_el = 4.08

S_vt = 3.56


length = 13.85
x_ht = 2.04
x_vt = 1.9
x_cg = 8.095
y_cg = 0.9
weight = 9610


engine1_y = 0.7
engine2_y = 1.2

Cg_y = 0.9
# Dihedral angle: 4.578°
Γ = 4.578 * π/180
𝚲0 = (90-80.2) * π/180

Vf = 59.2


y_vt = 1.2
z_vt = y_vt - y_cg
C_Du = 0.001
C_Lu = 0.004
C_mu = -0.001


x_w = 8.095

# %%
# Assumed quantities
ηT = 0.95
x_cg = length/2

# %%
#Derived quantities
λ = w_ct/w_cr
AR = b**2/S
AR_ht = b_ht**2/S_ht
sound_speed = np.sqrt(γ*R*Temperature)
M = Vinfty/sound_speed
q = 0.5*rho*Vinfty**2
β = np.sqrt(1/(1-M**2))
def Cdi_from_CL(CL, AR, e=0.9):
    return CL**2/(π*AR*e)
c_mac = (w_cr + w_ct) / 2

l_ht = x_cg - x_ht
hw = x_cg - x_cg

l_vt = l_ht

# %%
print("l_ht: ", l_ht)
print("c_mac: ", c_mac)
# Out:
# l_ht:  4.885
# c_mac:  2.8499999999999996

# %%
naca23012_data = pd.read_csv('xf-naca23012-il-1000000-n5.csv', skiprows=10)
naca23018_data = pd.read_csv('xf-naca23018-il-1000000-n5.csv', skiprows=10)
small_linear_region = 2.0

naca23012_data = naca23012_data[(naca23012_data['Alpha'] >= -small_linear_region) & (naca23012_data['Alpha'] <= small_linear_region)]
naca23018_data = naca23018_data[(naca23018_data['Alpha'] >= -small_linear_region) & (naca23018_data['Alpha'] <= small_linear_region)]
naca0010_data = naca23018_data[(naca23018_data['Alpha'] >= -small_linear_region) & (naca23018_data['Alpha'] <= small_linear_region)]

alpha_23012 = naca23012_data['Alpha'].values * np.pi/180
CL_23012 = naca23012_data['Cl'].values
alpha_23018 = naca23018_data['Alpha'].values * np.pi/180
CL_23018 = naca23018_data['Cl'].values
alpha_0010 = naca0010_data['Alpha'].values * np.pi/180
CL_0010 = naca0010_data['Cl'].values

CD_23012 = naca23012_data['Cd'].values
CD_23018 = naca23018_data['Cd'].values 

CLalpha_23012 = np.polyfit(alpha_23012, CL_23012, 1)[0]
CLalpha_23018 = np.polyfit(alpha_23018, CL_23018, 1)[0]

CDalpha_23012 = np.polyfit(alpha_23012, CD_23012, 1)[0]
CDalpha_23018 = np.polyfit(alpha_23018, CD_23018, 1)[0]

a_ht =( np.polyfit(alpha_0010, CL_0010, 1)[0])
a_vt = a_ht

Cd_alpha = (CDalpha_23012 + CDalpha_23018) / 2

print(f"NACA 23012 lift curve slope: {CLalpha_23012:.4f} per radian")
print(f"NACA 23018 lift curve slope: {CLalpha_23018:.4f} per radian")
print(f"NACA 0010 lift curve slope: {a_ht:.4f} per radian")

CLalpha_average = (CLalpha_23012 + CLalpha_23018) / 2
aw = (β * CLalpha_average / (1 + (2/AR)))


CL0 = np.average([0.1005, 0.1539, 0.1012, 0.1563])
CD0 = np.average([0.00736, 0.00724, 0.00822, 0.00831])


zero_lift_alpha_23012 = -1.2505 * np.pi/180
zero_lift_alpha_23018 = -1.250 * np.pi/180
α0Lw = (zero_lift_alpha_23012 + zero_lift_alpha_23018) / 2
α0LT = 0


α0LVT = 0

Cm0 = -0.0076
naca23012_cmac = -0.0089
naca23018_cmac = -0.0047
naca0010_cmac = 0.0
cmac_w = (naca23012_cmac + naca23018_cmac) / 2
# Out:
# NACA 23012 lift curve slope: 6.0484 per radian
# NACA 23018 lift curve slope: 6.2754 per radian
# NACA 0010 lift curve slope: 6.2754 per radian

# %%
ϵ0 = 2*aw*(iw - α0Lw)/(π*AR)
ϵα = 2 * aw/(π*AR)

Lift_required = weight * 9.81
Cl_stable = Lift_required / (q * S)

thrust = q * S * (CD0 + Cdi_from_CL(Cl_stable, AR)) 
thrust_moment = thrust * np.abs((engine1_y + engine2_y) / 2 - Cg_y)
Cm_thrust = thrust_moment / (q * S * c_mac)

# %%
Clα = aw + ηT * (S_ht/S) * a_ht * (1 - ϵα)
print("Clα: ", Clα)
CliT = ηT * (S_ht/S) * a_ht
Cl0 = aw*(iw - α0Lw) + ηT * (S_ht/S) * a_ht * (ϵ0 + α0LT)
print("Cl0: ", Cl0)
α = (Cl_stable - Cl0 - CliT * it) / Clα
print("Trim aoa in degrees= ", α * 180/np.pi)
# Out:
# Clα:  5.220491433903306
# Cl0:  0.1197209562746841
# Trim aoa in degrees=  2.73157488048059

# %%
def get_δe(α):
    Cm1 = cmac_w + Cm_thrust
    δe = np.sqrt((S/(S_ht_el*a_ht)))*((S/( ηT * S_ht))* ((aw*(α - α0Lw)*(x_w - x_cg)/c_mac + Cm1)/((x_cg - x_ht)/c_mac)) - a_ht*( α +  it - ϵ0 - ϵα*α))
    return δe

# %%
def get_lift(α):
    δ = get_δe(α)
    Lw = aw * S * q * α 
    Lt = a_ht * S_ht * q * ηT * (1-ϵα) * it
    Lδ = a_ht * S_ht_el * q * ηT * (1-ϵα) * δ
    return Lw + Lt + Lδ

# %%
aoas = []
lifts = []

for i in np.arange(-5, 15, 0.1):
    aoa = i * π / 180
    lift = get_lift(aoa)
    aoas.append(aoa)
    lifts.append(lift)

lifts = np.array(lifts)
aoas = np.array(aoas)

lifts = lifts - Lift_required
argmin = np.argmin(np.abs(lifts))
aoa = aoas[argmin]
deflection = get_δe(aoa)
print('Trim aoa:', aoa * 180/π)
print('Elevator deflection:', deflection * 180 / π)
θ = aoa
# Out:
# Trim aoa: 5.199999999999964
# Elevator deflection: -0.936629250397763

# %%
Vt =(S_ht + S_ht_el)*l_ht/(S*c_mac)
print("Vt: ",Vt)
# Out:
# Vt:  0.5177721576668946

# %%
print("x_cg: ", x_cg)
# Out:
# x_cg:  6.925

# %%
x_np = x_cg - ηT*Vt * (1-ϵα)
print("x_np: ", x_np)
# Out:
# x_np:  6.73501980261804

# %%
Cmcgα = (x_np - x_cg)/(c_mac*aw)
print("Cmcgα: ", Cmcgα)
# Out:
# Cmcgα:  -0.013977854557091484

# %%
C_hα_byC_hδ = 0.2
τ = 0.9
F = 1 - τ * C_hα_byC_hδ
print("F: ", F)
# Out:
# F:  0.82

# %%
Cmδe = - Vt * a_ht * ηT * τ
print("Cmδe: ", Cmδe)
# Out:
# Cmδe:  -2.778078826803208

# %%
C_lβ = -aw*Γ*((1+2*λ)/(6*(1+λ)))
print("C_lβ: ", C_lβ)
# Out:
# C_lβ:  -0.0846766366365378

# %%
Cmcg_free_alpha = Cm0 - aw*(x_cg- x_cg) - a_ht * ηT *Vt* (1 - ϵα) *F
print("Cmcg_free_alpha: ", Cmcg_free_alpha)
# Out:
# Cmcg_free_alpha:  -0.9852016894752842

# %%
x_np_free = x_np + (a_ht/aw) * ηT * Vt * (1 - ϵα) * (1-F)
print("x_np_free: ", x_np_free)
# Out:
# x_np_free:  6.780018261358078

# %%
C_Nβ  = 0.00006 * np.sqrt(𝚲0)
print("C_Nβ: ", C_Nβ )
# Out:
# C_Nβ:  2.481435391267722e-05

# %%
C_Nβf = -2*Vf/(S*b)
print("C_Nβf: ", C_Nβf)
# Out:
# C_Nβf:  -0.22284961415396196

# %%
C_Ypβ = 0.00235 * (1-ηT)
print("C_Ypβ: ", C_Ypβ)
# Out:
# C_Ypβ:  0.0001175000000000001

# %%
# V-Tail stuff
η_vt = 0.95
C_lβV = -a_vt * S_vt*z_vt*η_vt/(q*S*b)
print("C_lβV: ", C_lβV)
# Out:
# C_lβV:  -2.3032612091642387e-06

# %%
σ = 0
σb = 0
V_vt = S_vt * l_vt / (S * b)

C_NβV = η_vt * V_vt * a_vt *(1 + σb)

print("C_NβV: ", C_NβV)
# Out:
# C_NβV:  0.1951363206152763

# %%
# Pitch rate derivatives start here
C_Zq = - ηT * Vt * a_ht*c_mac/Vinfty
q_to_qbar = c_mac/(2*Vinfty)
C_Zqbar = C_Zq / q_to_qbar
print("C_Zq: ", C_Zq)
print("C_Zqbar: ", C_Zqbar)
print("q_to_qbar: ", q_to_qbar)

print()
C_mq = -ηT * Vt * a_ht * l_ht/Vinfty
C_mqbar = C_mq / q_to_qbar

print("C_mq: ", C_mq)
print("C_mqbar: ", C_mqbar)
# Out:
# C_Zq:  -0.07006658987954993
# C_Zqbar:  -6.173508504007129
# q_to_qbar:  0.011349557522123892
#
# C_mq:  -0.12009659353038646
# C_mqbar:  -10.581610190201694

# %%
# AOA rate impact
C_Zα = -a_ht * ϵα * c_mac * ηT * Vt /Vinfty
α_to_αbar = q_to_qbar
C_Zαbar = C_Zα / α_to_αbar
print("C_Zα: ", C_Zα)
print("C_Zαbar: ", C_Zαbar)
print("α_to_αbar: ", α_to_αbar)

C_mαdot = -ηT * a_ht * ϵα * Vt * l_ht / Vinfty
C_mαdotbar = C_mαdot / α_to_αbar
print("C_mα: ", C_mαdot)
print("C_mαbar: ", C_mαdotbar)
# Out:
# C_Zα:  -0.043004768883390804
# C_Zαbar:  -3.789114139433264
# α_to_αbar:  0.011349557522123892
# C_mα:  -0.07371168280539092
# C_mαbar:  -6.4946745863619295

# %%
# Yaw rate 
C_Yrbar = 2*aw *η_vt *( S_vt*l_vt)/(S*b)
C_Nrbar = -2*a_vt * η_vt * V_vt * (l_vt/b)

print("C_Yrbar: ", C_Yrbar)
print("C_Nrbar: ", C_Nrbar)
# Out:
# C_Yrbar:  0.2965864518066671
# C_Nrbar:  -0.13815085887038037

# %%
# Roll effects
C_lpbar = -Clα*(1+3*λ)/(12*(1+λ))
print("C_lpbar: ", C_lpbar)
# Out:
# C_lpbar:  -0.7250682547087925

# %%
# Longitudinal dynamics

Iyy = weight*((length/2.4)**2)
print("Iyy: ", Iyy)

# Calclulation of necessary coefficiencts:
Xu = - (-(C_Du + 2 * CD0) * q * S) / (weight * Vinfty)
Xw = -(Cd_alpha - Cl0)* (q * S) / (weight * Vinfty)
Zu = - ((C_Lu + 2 * CL0) * q * S) / (weight * Vinfty)
Zw = -(Clα  + CD0) * (q * S) / (weight * Vinfty)
Zq = -C_Zq * c_mac * q * S / (2 * Vinfty)
M_δe = Cmδe * q * S * c_mac / Iyy
X_δe = 0
X_δT = 0
Z_δe = 0
Z_δT = 0 
M_wdot = C_mαdot * (c_mac**2) * q * S / (2 * Vinfty * Iyy)
Mu = C_mu * q * S * c_mac / (Iyy * Vinfty)
Mw = Cmcgα * q * S * c_mac / (Iyy * Vinfty)
Mq = C_mq * (c_mac**2) * q * S / (Iyy * (2 * Vinfty))

print("Xu: ", Xu)
print("Xw: ", Xw)
print("Zu: ", Zu)
print("Zw: ", Zw)
print("Zq: ", Zq)
print("M_δe: ", M_δe)
print("X_δe: ", X_δe)
print("X_δT: ", X_δT)
print("Z_δe: ", Z_δe)
print("Z_δT: ", Z_δT)
print("M_wdot: ", M_wdot)
print("Mu: ", Mu)
print("Mw: ", Mw)
print("Mq: ", Mq)
# Out:
# Iyy:  320037.19184027775
# Xu:  0.002750074462553474
# Xw:  0.02128789984015927
# Zu:  -0.04315616399280263
# Zw:  -0.8679832555907923
# Zq:  159.29503732444704
# M_δe:  -4.955657782599655
# X_δe:  0
# X_δT:  0
# Z_δe:  0
# Z_δT:  0
# M_wdot:  -0.0014923545018243904
# Mu:  -1.4207602882092332e-05
# Mw:  -0.00019859180669080034
# Mq:  -0.0024314557094298

# %%
θ = 0
A = np.array([[Xu, Xw, 0, -g * np.cos(θ), 0, 0],
              [Zu, Zw, Zq + Vinfty, -g * np.sin(θ), 0, 9],
              [Mu + M_wdot*Zu, Mw + M_wdot*Zw, Mq + M_wdot*Vinfty, 0, 0, 0],
              [0, 0, 0, 1, 0, 0],
              [np.cos(θ), np.sin(θ), 0, 0, 0, 0],
              [-np.sin(θ), np.cos(θ), 0, 0, 0, 0]])

B = np.array([[X_δe , X_δT],
                [Z_δe, Z_δT],
                [M_δe + M_wdot*Z_δe, M_δe + M_wdot*Z_δT],
                [0, 0],
                [0, 0],
                [0, 0]])

# %%
# A matrix till 3 significant digits
A_pretty = A.copy()
for i in range(A.shape[0]):
    for j in range(A.shape[1]):
        A_pretty[i, j] = f"{A[i, j]:.2f}"

A_pretty
# Out:
# array([[ 0.0000e+00,  2.0000e-02,  0.0000e+00, -9.8100e+00,  0.0000e+00,
#          0.0000e+00],
#        [-4.0000e-02, -8.7000e-01,  2.8485e+02, -0.0000e+00,  0.0000e+00,
#          9.0000e+00],
#        [ 0.0000e+00,  0.0000e+00, -1.9000e-01,  0.0000e+00,  0.0000e+00,
#          0.0000e+00],
#        [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,
#          0.0000e+00],
#        [ 1.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00],
#        [-0.0000e+00,  1.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00]])

# %%
B
# Out:
# array([[ 0.        ,  0.        ],
#        [ 0.        ,  0.        ],
#        [-4.95565778, -4.95565778],
#        [ 0.        ,  0.        ],
#        [ 0.        ,  0.        ],
#        [ 0.        ,  0.        ]])
